# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, TransformerEncoder, Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\Code Ground\Data Science\Projects\Genrs-Classifiers\Gerns_pred_trans.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> from tensorflow.keras.models import Sequential
# ----> <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow.keras.layers import Embedding, TransformerEncoder, Dense
#
# ImportError: cannot import name 'TransformerEncoder' from 'tensorflow.keras.layers' (c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\api\_v2\keras\layers\__init__.py)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, TransformerEncoder, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import tensorflow as tf
import torch
from torch.utils.data import DataLoader, TensorDataset
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\Code Ground\Data Science\Projects\Genrs-Classifiers\Gerns_pred_trans.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow.keras.models import Sequential
# ----> <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> from tensorflow.keras.layers import Embedding, TransformerEncoder, Dense
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> from sklearn.model_selection import train_test_split
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> from sklearn.preprocessing import LabelEncoder
#
# ImportError: cannot import name 'TransformerEncoder' from 'tensorflow.keras.layers' (c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\api\_v2\keras\layers\__init__.py)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# file_path = "/content/drive/MyDrive/THWS/movie_dataset.txt"

file_path = "./movie_dataset.txt"

# %%
df = pd.read_csv(file_path, sep=':::', header=None)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Code Ground\Data Science\Projects\Genrs-Classifiers\Gerns_pred_trans.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv(file_path, sep=':::', header=None)
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# NameError: name 'pd' is not defined

# %%
col_names = ['sr_num', 'movie', 'genrs', 'des']
df.columns = col_names

# %%
df.drop(["sr_num"], axis=1, inplace=True)
df
# Out:
#                                               movie          genrs  \
# 0                     Oscar et la dame rose (2009)          drama
# 1                                     Cupid (1997)       thriller
# 2                 Young, Wild and Wonderful (1980)          adult
# 3                            The Secret Sin (1915)          drama
# 4                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54209                              "Bonino" (1953)         comedy
# 54210                  Dead Girls Don't Cry (????)         horror
# 54211    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212                     Make Your Own Bed (1944)         comedy
# 54213   Nature's Fury: Storm of the Century (2006)        history
#
#                                                      des
# 0       Listening in to a conversation between his do...
# 1       A brother and sister with a past incestuous r...
# 2       As the bus empties the students for their fie...
# 3       To help their unemployed father make ends mee...
# 4       The film's title refers not only to the un-re...
# ...                                                  ...
# 54209   This short-lived NBC live sitcom centered on ...
# 54210   The NEXT Generation of EXPLOITATION. The sist...
# 54211   Ze bestaan echt, is a stand-up comedy about g...
# 54212   Walter and Vivian live in the country and hav...
# 54213   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %%
df.genrs.value_counts()
# Out:
#  drama           13613
#  documentary     13096
#  comedy           7447
#  short            5073
#  horror           2204
#  thriller         1591
#  action           1315
#  western          1032
#  reality-tv        884
#  family            784
#  adventure         775
#  music             731
#  romance           672
#  sci-fi            647
#  adult             590
#  crime             505
#  animation         498
#  sport             432
#  talk-show         391
#  fantasy           323
#  mystery           319
#  musical           277
#  biography         265
#  history           243
#  game-show         194
#  news              181
#  war               132
# Name: genrs, dtype: int64

# %%
# add one clm as a length of the text
df['num_of_characters'] = df['des'].apply(len)
df.head()
# Out:
#                                 movie       genrs  \
# 0       Oscar et la dame rose (2009)       drama
# 1                       Cupid (1997)    thriller
# 2   Young, Wild and Wonderful (1980)       adult
# 3              The Secret Sin (1915)       drama
# 4             The Unrecovered (2007)       drama
#
#                                                  des  num_of_characters
# 0   Listening in to a conversation between his do...                546
# 1   A brother and sister with a past incestuous r...                184
# 2   As the bus empties the students for their fie...                650
# 3   To help their unemployed father make ends mee...               1082
# 4   The film's title refers not only to the un-re...                625

# %%
df[df["num_of_characters"] > 3000].count()
# Out:
# movie                189
# genrs                189
# des                  189
# num_of_characters    189
# dtype: int64

# %%
df = df[df["num_of_characters"] < 3000]

# %%
df["num_of_characters"].describe()
# Out:
# count    54024.000000
# mean       588.453224
# std        390.928163
# min         42.000000
# 25%        325.000000
# 50%        463.000000
# 75%        709.000000
# max       2998.000000
# Name: num_of_characters, dtype: float64

# %%
# applying stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['des_stemmed'] = df['des'].apply(
    lambda x: ' '.join([st.stem(word) for word in x.split()]))
# Out:
# <ipython-input-12-08d98a47098a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['des_stemmed'] = df['des'].apply(

# %%
# Tokenize the descriptions
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(df['des'])
sequences = tokenizer.texts_to_sequences(df['des'])

# %%
# Pad sequences to have consistent length
padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Code Ground\Data Science\Projects\Genrs-Classifiers\Gerns_pred_trans.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # Pad sequences to have consistent length
# ----> <a href='vscode-notebook-cell:/e%3A/Code%20Ground/Data%20Science/Projects/Genrs-Classifiers/Gerns_pred_trans.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> padded_sequences = tf.keras.preprocessing.sequence.pad_sequences(sequences)
#
# NameError: name 'sequences' is not defined
